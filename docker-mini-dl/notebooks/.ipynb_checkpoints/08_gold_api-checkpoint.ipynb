# %%
import sys
from pathlib import Path
import io
import pandas as pd

sys.path.append(str(Path.cwd().parent))

from src.storage.minio_client import read_parquet
from src.storage.minio_client import upload_bytes

# %%
df_bronze = read_parquet(
    bucket_name="bronze",
    object_name="networks.parquet"
)

df_bronze.head()
# Out:
#                       id                   name  \
# 0  abu-dhabi-careem-bike  Abu Dhabi Careem BIKE
# 1    acces-velo-saguenay             Accès Vélo
# 2                   aksu                   Aksu
# 3                   alba                   Alba
# 4               albabici               AlbaBici
#
#                                             location  \
# 0  {'city': 'Abu Dhabi', 'country': 'AE', 'latitu...
# 1  {'city': 'Saguenay', 'country': 'CA', 'latitud...
# 2  {'city': '阿克苏市 (Aksu City)', 'country': 'CN', ...
# 3  {'city': 'Alba', 'country': 'IT', 'latitude': ...
# 4  {'city': 'Albacete', 'country': 'ES', 'latitud...
#
#                                  href  \
# 0  /v2/networks/abu-dhabi-careem-bike
# 1    /v2/networks/acces-velo-saguenay
# 2                   /v2/networks/aksu
# 3                   /v2/networks/alba
# 4               /v2/networks/albabici
#
#                                              company  \
# 0                                           [Careem]
# 1                             [PBSC Urban Solutions]
# 2                                          [阿克苏公共服务]
# 3                                [Comunicare S.r.l.]
# 4  [Instituto Tecnológico de Castilla y León (ITCL)]
#
#                                            gbfs_href      system  \
# 0  https://dubai.publicbikesystem.net/customer/gb...        None
# 1  https://saguenay.publicbikesystem.net/customer...        None
# 2                                               None        None
# 3                                               None  Bicincittà
# 4                                               None    bicicard
#
#                                               source ebikes license scooters  \
# 0                                               None   None    None     None
# 1                                               None   None    None     None
# 2                                               None   None    None     None
# 3  https://www.bicincitta.com/frmLeStazioni.aspx?...   None    None     None
# 4                                               None   None    None     None
#
#   instances
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
df_bronze.shape
# Out:
# (800, 12)

# %%
df_bronze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         800 non-null    object
#  1   name       800 non-null    object
#  2   location   800 non-null    object
#  3   href       800 non-null    object
#  4   company    800 non-null    object
#  5   gbfs_href  272 non-null    object
#  6   system     549 non-null    object
#  7   source     212 non-null    object
#  8   ebikes     46 non-null     object
#  9   license    77 non-null     object
#  10  scooters   2 non-null      object
#  11  instances  1 non-null      object
# dtypes: object(12)
# memory usage: 75.1+ KB

# %%
df_bronze.columns.tolist()
# Out:
# ['id',
#  'name',
#  'location',
#  'href',
#  'company',
#  'gbfs_href',
#  'system',
#  'source',
#  'ebikes',
#  'license',
#  'scooters',
#  'instances']

# %%
location = pd.json_normalize(df_bronze["location"])

# %%
df_silver = df_bronze.drop(columns=["location"])

# %%
df_silver = pd.concat(
    [
        df_silver.reset_index(drop=True),
        location.reset_index(drop=True)
    ],
    axis=1
)

# %%
df_silver.head()
# Out:
#                       id                   name  \
# 0  abu-dhabi-careem-bike  Abu Dhabi Careem BIKE
# 1    acces-velo-saguenay             Accès Vélo
# 2                   aksu                   Aksu
# 3                   alba                   Alba
# 4               albabici               AlbaBici
#
#                                  href  \
# 0  /v2/networks/abu-dhabi-careem-bike
# 1    /v2/networks/acces-velo-saguenay
# 2                   /v2/networks/aksu
# 3                   /v2/networks/alba
# 4               /v2/networks/albabici
#
#                                              company  \
# 0                                           [Careem]
# 1                             [PBSC Urban Solutions]
# 2                                          [阿克苏公共服务]
# 3                                [Comunicare S.r.l.]
# 4  [Instituto Tecnológico de Castilla y León (ITCL)]
#
#                                            gbfs_href      system  \
# 0  https://dubai.publicbikesystem.net/customer/gb...        None
# 1  https://saguenay.publicbikesystem.net/customer...        None
# 2                                               None        None
# 3                                               None  Bicincittà
# 4                                               None    bicicard
#
#                                               source ebikes license scooters  \
# 0                                               None   None    None     None
# 1                                               None   None    None     None
# 2                                               None   None    None     None
# 3  https://www.bicincitta.com/frmLeStazioni.aspx?...   None    None     None
# 4                                               None   None    None     None
#
#   instances              city country   latitude  longitude
# 0      None         Abu Dhabi      AE  24.486600  54.372800
# 1      None          Saguenay      CA  48.433333 -71.083333
# 2      None  阿克苏市 (Aksu City)      CN  41.166400  80.261700
# 3      None              Alba      IT  44.716667   8.083333
# 4      None          Albacete      ES  38.994300  -1.860200

# %%
df_silver["company"] = df_silver["company"].apply(
    lambda x: ", ".join(x) if isinstance(x, list) else x
)

# %%
columns = [
    "id",
    "name",
    "city",
    "country",
    "latitude",
    "longitude",
    "company",
    "system",
    "href"
]

df_silver = df_silver[columns]

# %%
df_silver = df_silver.rename(
    columns={
        "id": "network_id",
        "name": "network_name"
    }
)

# %%
df_silver.dtypes
# Out:
# network_id       object
# network_name     object
# city             object
# country          object
# latitude        float64
# longitude       float64
# company          object
# system           object
# href             object
# dtype: object

# %%
df_silver["latitude"] = pd.to_numeric(
    df_silver["latitude"],
    errors="coerce"
)

df_silver["longitude"] = pd.to_numeric(
    df_silver["longitude"],
    errors="coerce"
)

# %%
df_silver.isna().sum()
# Out:
# network_id        0
# network_name      0
# city              0
# country           0
# latitude          0
# longitude         0
# company           0
# system          251
# href              0
# dtype: int64

# %%
df_silver["network_id"].duplicated().sum()
# Out:
# 0

# %%
buffer = io.BytesIO()

df_silver.to_parquet(
    buffer,
    index=False
)

buffer.seek(0)
# Out:
# 0

# %%
upload_bytes(
    bucket_name="silver",
    object_name="networks_clean.parquet",
    data=buffer.getvalue(),
    content_type="application/octet-stream"
)
# Out:
# Archivo 'networks_clean.parquet' subido correctamente al bucket 'silver'.
