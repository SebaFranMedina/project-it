# %%
import sys
from pathlib import Path

# Añadir la raíz del proyecto al path
sys.path.append(str(Path.cwd().parent))

# %%
from src.generators.sales import generate_sales

# %%
generate_sales(
    num_rows=100000,
    start_id=65000,
    output_file="ventas.csv"
)
# Out:
# Generadas 100000 ventas en /home/jovyan/work/datasets/raw/ventas.csv
