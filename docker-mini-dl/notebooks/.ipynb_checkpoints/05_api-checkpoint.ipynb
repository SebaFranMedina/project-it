# %%
import sys
from pathlib import Path

# Añadir la raíz del proyecto al path
sys.path.append(str(Path.cwd().parent))

from src.api.citybikes import get_networks
from src.storage.minio_client import upload_file
import json

# %%
raw_dir = Path("../datasets/raw")
raw_dir.mkdir(parents=True, exist_ok=True)

# %%
data = get_networks()

# %%
data.keys()
# Out:
# dict_keys(['networks'])

# %%
json_path = raw_dir / "networks.json"

with open(json_path, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print(f"Guardado en: {json_path}")
# Out:
# Guardado en: ../datasets/raw/networks.json

# %%
## Subirlo a Minio

upload_file(
    bucket_name="raw",
    file_path="datasets/raw/networks.json"
)
# Out:
# Archivo 'networks.json' subido correctamente al bucket 'raw'.
