# %%
import sys
from pathlib import Path
import pandas as pd
from sqlalchemy import create_engine
sys.path.append(str(Path.cwd().parent))

from src.storage.minio_client import read_parquet

# %%
dim_city = read_parquet(
    bucket_name="gold",
    object_name="dim_city.parquet"
)

# %%
dim_system = read_parquet(
    bucket_name="gold",
    object_name="dim_system.parquet"
)

# %%
fact_network = read_parquet(
    bucket_name="gold",
    object_name="fact_network.parquet"
)

# %%
# Hay que instalarse esta librería. 
# %pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Downloading psycopg2_binary-2.9.12-cp311-cp311-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 33.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.12
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@postgres:5432/dw"
)

# %%
with engine.connect() as conn:
    print("Conexión a PostgreSQL OK")
# Out:
# Conexión a PostgreSQL OK

# %%
dim_city.to_sql(
    "dim_city",
    engine,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2112, in Connection._exec_insertmany_context(self, dialect, context)
#    2111     else:
# -> 2112         dialect.do_execute(
#    2113             cursor,
#    2114             sub_stmt,
#    2115             sub_params,
#    2116             context,
#    2117         )
#    2119 except BaseException as e:
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# UniqueViolation: duplicate key value violates unique constraint "dim_city_pkey"
# DETAIL:  Key (city_key)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dim_city.to_sql(
#       2     "dim_city",
#       3     engine,
#       4     if_exists="append",
#       5     index=False
#       6 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     514     if TYPE_CHECKING:
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#     520     raise exc.ObjectNotExecutableError(self)
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1639, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1628     "compiled_cache", self.engine._compiled_cache
#    1629 )
#    1631 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1632     dialect=dialect,
#    1633     compiled_cache=compiled_cache,
#    (...)
#    1637     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1638 )
# -> 1639 ret = self._execute_context(
#    1640     dialect,
#    1641     dialect.execution_ctx_cls._init_compiled,
#    1642     compiled_sql,
#    1643     distilled_parameters,
#    1644     execution_options,
#    1645     compiled_sql,
#    1646     distilled_parameters,
#    1647     elem,
#    1648     extracted_params,
#    1649     cache_hit=cache_hit,
#    1650 )
#    1651 if has_events:
#    1652     self.dispatch.after_execute(
#    1653         self,
#    1654         elem,
#    (...)
#    1658         ret,
#    1659     )
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1840 context.pre_exec()
#    1842 if context.execute_style is ExecuteStyle.INSERTMANYVALUES:
# -> 1843     return self._exec_insertmany_context(
#    1844         dialect,
#    1845         context,
#    1846     )
#    1847 else:
#    1848     return self._exec_single_context(
#    1849         dialect, context, statement, parameters
#    1850     )
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2120, in Connection._exec_insertmany_context(self, dialect, context)
#    2112         dialect.do_execute(
#    2113             cursor,
#    2114             sub_stmt,
#    2115             sub_params,
#    2116             context,
#    2117         )
#    2119 except BaseException as e:
# -> 2120     self._handle_dbapi_exception(
#    2121         e,
#    2122         sql_util._long_statement(sub_stmt),
#    2123         sub_params,
#    2124         cursor,
#    2125         context,
#    2126         is_sub_exec=True,
#    2127     )
#    2129 if engine_events:
#    2130     self.dispatch.after_cursor_execute(
#    2131         self,
#    2132         cursor,
#    (...)
#    2136         context.executemany,
#    2137     )
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2343, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2341 elif should_wrap:
#    2342     assert sqlalchemy_exception is not None
# -> 2343     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2344 else:
#    2345     assert exc_info[1] is not None
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2112, in Connection._exec_insertmany_context(self, dialect, context)
#    2110             break
#    2111     else:
# -> 2112         dialect.do_execute(
#    2113             cursor,
#    2114             sub_stmt,
#    2115             sub_params,
#    2116             context,
#    2117         )
#    2119 except BaseException as e:
#    2120     self._handle_dbapi_exception(
#    2121         e,
#    2122         sql_util._long_statement(sub_stmt),
#    (...)
#    2126         is_sub_exec=True,
#    2127     )
#
# File /opt/conda/lib/python3.11/site-packages/sqlalchemy/engine/default.py:922, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     921 def do_execute(self, cursor, statement, parameters, context=None):
# --> 922     cursor.execute(statement, parameters)
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "dim_city_pkey"
# DETAIL:  Key (city_key)=(1) already exists.
#
# [SQL: INSERT INTO dim_city (city_key, city, country) VALUES (%(city_key__0)s, %(city__0)s, %(country__0)s), (%(city_key__1)s, %(city__1)s, %(country__1)s), (%(city_key__2)s, %(city__2)s, %(country__2)s), (%(city_key__3)s, %(city__3)s, %(country__3)s), (%(c ... 40682 characters truncated ... y_key__763)s, %(city__763)s, %(country__763)s), (%(city_key__764)s, %(city__764)s, %(country__764)s)]
# [parameters: {'country__0': 'AE', 'city__0': 'Abu Dhabi', 'city_key__0': 1, 'country__1': 'CA', 'city__1': 'Saguenay', 'city_key__1': 2, 'country__2': 'CN', 'city__2': '阿克苏市 (Aksu City)', 'city_key__2': 3, 'country__3': 'IT', 'city__3': 'Alba', 'city_key__3': 4, 'country__4': 'ES', 'city__4': 'Albacete', 'city_key__4': 5, 'country__5': 'PT', 'city__5': 'Almeirim', 'city_key__5': 6, 'country__6': 'ES', 'city__6': 'León', 'city_key__6': 7, 'country__7': 'FR', 'city__7': 'Saint-Pierre', 'city_key__7': 8, 'country__8': 'ES', 'city__8': 'Barcelona', 'city_key__8': 9, 'country__9': 'ES', 'city__9': 'Badalona', 'city_key__9': 10, 'country__10': 'ES', 'city__10': 'Castelldefels', 'city_key__10': 11, 'country__11': 'ES', 'city__11': 'Cornellà de Llobregat', 'city_key__11': 12, 'country__12': 'ES', 'city__12': 'El Prat de Llobregat', 'city_key__12': 13, 'country__13': 'ES', 'city__13': 'Esplugues de Llobregat', 'city_key__13': 14, 'country__14': 'ES', 'city__14': 'Gavà', 'city_key__14': 15, 'country__15': 'ES', 'city__15': 'Hospitalet de Llobregat', 'city_key__15': 16, 'country__16': 'ES', 'city__16': 'Molins de Rei' ... 2195 parameters truncated ... 'city__748': '新竹市 Hsinchu City', 'city_key__748': 749, 'country__749': 'TW', 'city__749': '新竹縣 Hsinchu County', 'city_key__749': 750, 'country__750': 'TW', 'city__750': '新竹科學工業園區 Hsinchu Science Park', 'city_key__750': 751, 'country__751': 'TW', 'city__751': '高雄市 Kaohsiung City', 'city_key__751': 752, 'country__752': 'TW', 'city__752': '台灣 Miaoli County', 'city_key__752': 753, 'country__753': 'TW', 'city__753': '新北市 New Taipei', 'city_key__753': 754, 'country__754': 'TW', 'city__754': '屏東縣 Pingtung County', 'city_key__754': 755, 'country__755': 'CN', 'city__755': '莆田市 (Putian City)', 'city_key__755': 756, 'country__756': 'TW', 'city__756': '臺中市 Taichung City', 'city_key__756': 757, 'country__757': 'TW', 'city__757': '臺南市 Tainan City', 'city_key__757': 758, 'country__758': 'TW', 'city__758': '台北市 Taipei City', 'city_key__758': 759, 'country__759': 'TW', 'city__759': '臺東縣 Taitung County', 'city_key__759': 760, 'country__760': 'TW', 'city__760': '桃園市 Taoyuan City', 'city_key__760': 761, 'country__761': 'CH', 'city__761': 'Yverdon-les-Bains', 'city_key__761': 762, 'country__762': 'PL', 'city__762': 'Żary', 'city_key__762': 763, 'country__763': 'FR', 'city__763': 'Reims', 'city_key__763': 764, 'country__764': 'IT', 'city__764': 'Genova', 'city_key__764': 765}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
dim_system.to_sql(
    "dim_system",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 39

# %%
fact_network.to_sql(
    "fact_network",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 800
