# %%
import sys
from pathlib import Path
import pandas as pd
from sqlalchemy import create_engine
sys.path.append(str(Path.cwd().parent))

from src.storage.minio_client import read_parquet

# %%
dim_city = read_parquet(
    bucket_name="gold",
    object_name="dim_city.parquet"
)

# %%
dim_system = read_parquet(
    bucket_name="gold",
    object_name="dim_system.parquet"
)

# %%
fact_network = read_parquet(
    bucket_name="gold",
    object_name="fact_network.parquet"
)

# %%
# %pip install psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 33.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@postgres:5432/dw"
)

# %%
with engine.connect() as conn:
    print("Conexión a PostgreSQL OK")
# Out:
# Conexión a PostgreSQL OK

# %%
dim_city.to_sql(
    "dim_city",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 765

# %%
dim_system.to_sql(
    "dim_system",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 39

# %%
fact_network.to_sql(
    "fact_network",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 800
